# %% [markdown]
# https://www.geeksforgeeks.org/learn-data-structures-and-algorithms-dsa-tutorial/?ref=shm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  1. DSA

# %% [markdown]
# ### 1.1. What is DSA ?
#
# DSA : Data Structures and Algorithms

# %% [markdown]
# ### 1.2. What is Data Structure?
#
# A perticular way of storing and organizing data in our device to use th data efficiently and effectively.

# %% [markdown]
# ### 1.3. What is Algorithm?
# 1. A process or set of well-defined instructions that are typically used to solve a particular group of problems or perform a specific type of calculation.
# 1. Set of operations perfromed is a step-by-step manner to execute a task.

# %% [markdown]
# # 2. Complexities

# %% [markdown]
# ### 2.1. Time Complexity :
# Used to measure the amount of time required to execute the code.

# %% [markdown]
# ### 2.2. Space Compelxity
# Amount of space required to execute successfully the functionalities of the code.

# %% [markdown]
# ### 2. 3. Auxiliary Space:
# Extra space used in the program other than the input data structure.

# %% [markdown]
# # Asymtotic Notation
# 1. A mathematical tools that calculates the required time in terms of input size and does not require the execution of the code.
# 1. It neglects the system-dependent constants and is related to only the number of modular operations being performed in the whole program.
# 1. Type
#     - Bin-O Notation (O) : represents Worst-Case Scenario.
#     - Omega Notation (Ω) : represents Best-Case Scenario.
#     - Theta Notetion (θ) : represents Average Complexity.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Big-O Notation
